# %%
import pandas as pd
import numpy as np
import os

# %%
data = pd.read_csv("aapl_eod_201901.txt", sep=",")

# %%
data[data[" [QUOTE_DATE]"] == ' 2019-01-02']
# Out:
#      [QUOTE_UNIXTIME]   [QUOTE_READTIME]  [QUOTE_DATE]   [QUOTE_TIME_HOURS]  \
# 0          1546462800   2019-01-02 16:00    2019-01-02                 16.0
# 1          1546462800   2019-01-02 16:00    2019-01-02                 16.0
# 2          1546462800   2019-01-02 16:00    2019-01-02                 16.0
# 3          1546462800   2019-01-02 16:00    2019-01-02                 16.0
# 4          1546462800   2019-01-02 16:00    2019-01-02                 16.0
# ..                ...                ...           ...                  ...
# 790        1546462800   2019-01-02 16:00    2019-01-02                 16.0
# 791        1546462800   2019-01-02 16:00    2019-01-02                 16.0
# 792        1546462800   2019-01-02 16:00    2019-01-02                 16.0
# 793        1546462800   2019-01-02 16:00    2019-01-02                 16.0
# 794        1546462800   2019-01-02 16:00    2019-01-02                 16.0
#
# ...
